# %% [markdown]
# # Demo

# %% [markdown]
# Import the required dependencies

# %%
from typing import Tuple

from numpy import arange
from tensorflow import Tensor
from tensorflow.python.data import Dataset

from tfdatacompose import Map, Filter, Pipeline, Skip, Take
# Out:
# 2025-03-06 22:31:51.251826: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-06 22:31:51.659464: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-06 22:31:51.660647: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-06 22:31:52.687297: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 7
#       4 from tensorflow import Tensor
#       5 from tensorflow.python.data import Dataset
# ----> 7 from tfdatacompose import Map, Filter, Pipeline, Skip, Take
#
# ImportError: cannot import name 'Map' from 'tfdatacompose' (/home/francois/git/tf-data-compose/src/tfdatacompose/__init__.py)

# %% [markdown]
# Define the transformations

# %%
class Double(Map):
    def map(self, number: int) -> Tuple[Tensor, ...]:
        return number * 2

class RemoveOdd(Filter):
    def filter(self, number: int) -> bool:
        return number % 2 == 0

# %% [markdown]
# Create a transformation pipeline using our custom transformations

# %%
pipeline = Pipeline([
    Skip(10),
    RemoveOdd(),
    Double(),
    Take(10),
])

pipeline

# %% [markdown]
# Apply our transformation to a dataset

# %%
dataset = Dataset.from_tensor_slices(range(100))
result = pipeline(dataset)

dataset, result
# Out:
# (<_TensorSliceDataset element_spec=TensorSpec(shape=(), dtype=tf.int32, name=None)>,
#  <_TakeDataset element_spec=TensorSpec(shape=(), dtype=tf.int32, name=None)>)

# %% [markdown]
# Print the result of our dataset

# %%
resultList = list(result.as_numpy_iterator())
resultList
# Out:
# [20, 24, 28, 32, 36, 40, 44, 48, 52, 56]
